# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('subway.xlsx')

# %%
df.head(5)
# Out:
#           날짜   호선  역번호   역명  구분  05 ~ 06  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  \
# 0 2018-01-01  1호선  150  서울역  승차      373      318      365      785     1047
# 1 2018-01-01  1호선  150  서울역  하차      205     1040      872      984     1650
# 2 2018-01-01  1호선  151   시청  승차       87      105      124      197      291
# 3 2018-01-01  1호선  151   시청  하차       47      294      497     1017      673
# 4 2018-01-01  1호선  152   종각  승차      604      399      191      250      370
#
#    ...  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  22 ~ 23  \
# 0  ...     3476     3891     3227     2945     2382     3070     1750
# 1  ...     2885     2845     2337     2131     1669     1404      868
# 2  ...     1027     1102     1278     1163     1032      975      553
# 3  ...      781      702      552      388      308      236      160
# 4  ...     2127     2172     2171     1873     1935     2084     1458
#
#    23 ~ 24  00 ~ 01    합 계
# 0      781       96  40393
# ...

# %%
df.groupby(["역번호","역명"]).sum().sort_values(by="합 계",ascending=False)
# Out:
#                05 ~ 06  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  10 ~ 11  11 ~ 12  \
# 역번호  역명
# 222  강남         347810   991032  2693548  5177981  5182491  3023880  2943121
# 216  잠실(송파구청)   250924  1154965  2820172  4741891  3993852  2727013  2908547
# 239  홍대입구       594055   743409  1393165  2581530  2531757  2074661  2325106
# 230  신림         603943  1287469  3300251  4955753  3159124  2002757  1899092
# 232  구로디지털단지    603304   962639  2728893  5656724  3485354  1761124  1548813
# ...                ...      ...      ...      ...      ...      ...      ...
# 434  남태령          9288    35469   176334   290293   157066    94083    87209
# 2711 장암          17788   100616   236819   176408    80608    63249    48677
# 245  신답          14733    34283    90724   139523    60557    45840    43017
# 309  지축          12783    53025    79715    91966    63873    48335    44868
# 247  도림천          9447    26038   101528   111020    52137    41786    33959
#
# ...

# %%
df.groupby(["역번호","역명","구분"]).sum().sort_values(by="합 계",ascending=False)
# Out:
#                   05 ~ 06  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  10 ~ 11  \
# 역번호  역명       구분
# 222  강남       하차   148817   690650  2119634  4251476  4385965  2227121
#               승차   198993   300382   573914   926505   796526   796759
# 216  잠실(송파구청) 승차   177499   646233  1692468  2470574  1750942  1206908
#               하차    73425   508732  1127704  2271317  2242910  1520105
# 239  홍대입구     하차    60452   253760   482823  1443973  1650299  1280140
# ...                   ...      ...      ...      ...      ...      ...
# 309  지축       승차     4976    18494    58563    66493    42912    29758
# 247  도림천      하차     4533    10768    61273    71878    26361    19421
# 434  남태령      하차     1210    13955    50738    73241    28361    17185
# 247  도림천      승차     4914    15270    40255    39142    25776    22365
# 2711 장암       하차     2190    16861    18185    26062    25955    29711
#
#                   11 ~ 12  12 ~ 13  13 ~ 14  14 ~ 15  ...  16 ~ 17  17 ~ 18  \
# ...
